# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pickle
import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = '/home/user/Documents/Task/dataset/train/'
val_dataset_path = '/home/user/Documents/Task/dataset/val/'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_data_generate = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_data_generate.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 4411 images belonging to 2 classes.

# %%
val_data_generate = ImageDataGenerator(rescale=1.0/255)
val_generator = val_data_generate.flow_from_directory(val_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 70 images belonging to 2 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : metal
# 1 : plastic

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=2, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 128)     9728
#
#  activation (Activation)     (None, 146, 146, 128)     0
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 73, 73, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 71, 71, 64)        73792
#
#  activation_1 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 35, 35, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 32)        18464
#
#  activation_2 (Activation)   (None, 33, 33, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 2200802 (8.40 MB)
# Trainable params: 2200354 (8.39 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator,
                        epochs=50,
                        validation_data=val_generator,
                        verbose=2,
                        callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 138/138 - 529s - loss: 1.6824 - accuracy: 0.6971 - val_loss: 2.4000 - val_accuracy: 0.5143 - lr: 0.0010 - 529s/epoch - 4s/step
# Epoch 2/50
# 138/138 - 531s - loss: 0.8348 - accuracy: 0.7645 - val_loss: 1.8474 - val_accuracy: 0.5000 - lr: 0.0010 - 531s/epoch - 4s/step
# Epoch 3/50
# 138/138 - 518s - loss: 0.5336 - accuracy: 0.7966 - val_loss: 0.9271 - val_accuracy: 0.6000 - lr: 0.0010 - 518s/epoch - 4s/step
# Epoch 4/50
# 138/138 - 473s - loss: 0.4590 - accuracy: 0.8155 - val_loss: 0.6208 - val_accuracy: 0.7571 - lr: 0.0010 - 473s/epoch - 3s/step
# Epoch 5/50
# 138/138 - 524s - loss: 0.4067 - accuracy: 0.8404 - val_loss: 0.5957 - val_accuracy: 0.7571 - lr: 0.0010 - 524s/epoch - 4s/step
# Epoch 6/50
# 138/138 - 510s - loss: 0.3832 - accuracy: 0.8415 - val_loss: 0.5430 - val_accuracy: 0.7286 - lr: 0.0010 - 510s/epoch - 4s/step
# Epoch 7/50
# 138/138 - 500s - loss: 0.3648 - accuracy: 0.8533 - val_loss: 0.5700 - val_accuracy: 0.8286 - lr: 0.0010 - 500s/epoch - 4s/step
# Epoch 8/50
# 138/138 - 526s - loss: 0.3473 - accuracy: 0.8626 - val_loss: 0.5814 - val_accuracy: 0.7857 - lr: 0.0010 - 526s/epoch - 4s/step
# Epoch 9/50
# 138/138 - 477s - loss: 0.3402 - accuracy: 0.8597 - val_loss: 0.5893 - val_accuracy: 0.8286 - lr: 0.0010 - 477s/epoch - 3s/step
# Epoch 10/50
# 138/138 - 473s - loss: 0.3480 - accuracy: 0.8588 - val_loss: 1.0787 - val_accuracy: 0.5571 - lr: 0.0010 - 473s/epoch - 3s/step
# Epoch 11/50
# 138/138 - 472s - loss: 0.3377 - accuracy: 0.8681 - val_loss: 2.4253 - val_accuracy: 0.5429 - lr: 0.0010 - 472s/epoch - 3s/step
# Epoch 12/50
# 138/138 - 474s - loss: 0.2943 - accuracy: 0.8866 - val_loss: 0.5132 - val_accuracy: 0.8571 - lr: 3.1623e-04 - 474s/epoch - 3s/step
# Epoch 13/50
# 138/138 - 476s - loss: 0.2707 - accuracy: 0.8953 - val_loss: 0.4207 - val_accuracy: 0.8714 - lr: 3.1623e-04 - 476s/epoch - 3s/step
# Epoch 14/50
# 138/138 - 475s - loss: 0.2614 - accuracy: 0.8991 - val_loss: 0.3839 - val_accuracy: 0.8429 - lr: 3.1623e-04 - 475s/epoch - 3s/step
# Epoch 15/50
# 138/138 - 474s - loss: 0.2489 - accuracy: 0.9061 - val_loss: 0.4820 - val_accuracy: 0.8571 - lr: 3.1623e-04 - 474s/epoch - 3s/step
# Epoch 16/50
# 138/138 - 473s - loss: 0.2475 - accuracy: 0.9030 - val_loss: 0.3286 - val_accuracy: 0.8857 - lr: 3.1623e-04 - 473s/epoch - 3s/step
# Epoch 17/50
# 138/138 - 473s - loss: 0.2332 - accuracy: 0.9141 - val_loss: 0.4303 - val_accuracy: 0.8571 - lr: 3.1623e-04 - 473s/epoch - 3s/step
# Epoch 18/50
# 138/138 - 472s - loss: 0.2266 - accuracy: 0.9089 - val_loss: 0.3614 - val_accuracy: 0.9000 - lr: 3.1623e-04 - 472s/epoch - 3s/step
# Epoch 19/50
# 138/138 - 471s - loss: 0.2304 - accuracy: 0.9098 - val_loss: 0.2745 - val_accuracy: 0.9143 - lr: 3.1623e-04 - 471s/epoch - 3s/step
# Epoch 20/50
# 138/138 - 471s - loss: 0.2217 - accuracy: 0.9134 - val_loss: 0.2745 - val_accuracy: 0.9143 - lr: 3.1623e-04 - 471s/epoch - 3s/step
# Epoch 21/50
# 138/138 - 471s - loss: 0.2241 - accuracy: 0.9102 - val_loss: 0.5502 - val_accuracy: 0.7857 - lr: 3.1623e-04 - 471s/epoch - 3s/step
# Epoch 22/50
# 138/138 - 470s - loss: 0.2144 - accuracy: 0.9184 - val_loss: 0.3506 - val_accuracy: 0.8714 - lr: 3.1623e-04 - 470s/epoch - 3s/step
# Epoch 23/50
# 138/138 - 11229s - loss: 0.2178 - accuracy: 0.9204 - val_loss: 0.3804 - val_accuracy: 0.8571 - lr: 3.1623e-04 - 11229s/epoch - 81s/step
# Epoch 24/50
# 138/138 - 295s - loss: 0.2182 - accuracy: 0.9154 - val_loss: 0.4340 - val_accuracy: 0.8286 - lr: 3.1623e-04 - 295s/epoch - 2s/step
# Epoch 25/50
# 138/138 - 452s - loss: 0.1846 - accuracy: 0.9259 - val_loss: 0.3030 - val_accuracy: 0.8857 - lr: 1.0000e-04 - 452s/epoch - 3s/step
# Epoch 26/50

# %%
pickle.dump(model, open('model.pkl', 'wb'))

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = '/home/user/Documents/Task/dataset/test/'

# %%
test_data_generate = ImageDataGenerator(rescale=1.0/255)
test_generator = test_data_generate.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')

# %%
predictions = cnn_model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
